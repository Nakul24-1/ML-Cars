# %% [markdown]
# <a href="https://colab.research.google.com/github/Nakul24-1/ML-Cars/blob/main/ML_Cars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dataset <- read.csv(file = "/content/cars.csv",header=TRUE,fill = T,na.strings = "")

# %%
head(dataset,2)
# Out:
#   X                                           V1      V2
# 1 X                                           MSRP    Gas Mileage
# 2 X2019.Acura.RDX.Specs..FWD.w.Technology.Pkg $40,600 22 mpg City/28 mpg Hwy
#   V3                                V4
# 1 Engine                            EPA Class
# 2 Turbo Premium Unleaded I-4, 2.0 L Small Sport Utility Vehicles 2WD
#   V5                   V6                V7                 V8
# 1 Style Name           Drivetrain        Passenger Capacity Passenger Doors
# 2 FWD w/Technology Pkg Front Wheel Drive 5                  4
#   V9            ⋯ V225                 V226
# 1 Body Style    ⋯ Fourth Hip Room (in) Fourth Leg Room (in)
# 2 Sport Utility ⋯ NA                   NA
#   V227                      V228                  V229
# 1 Fourth Shoulder Room (in) Fourth Head Room (in) Fifth Shoulder Room (in)
# 2 NA                        NA                    NA
#   V230                 V231                V232                V233
# ...

# %%
c(dataset[(1),])
# Out:
# $X
# [1] "X"
#
# $V1
# [1] "MSRP"
#
# $V2
# [1] "Gas Mileage"
#
# $V3
# [1] "Engine"
#
# $V4
# [1] "EPA Class"
#
# $V5
# [1] "Style Name"
#
# $V6
# [1] "Drivetrain"
#
# $V7
# [1] "Passenger Capacity"
#
# $V8
# [1] "Passenger Doors"
#
# $V9
# [1] "Body Style"
#
# $V10
# [1] "Transmission"
#
# $V11
# [1] "EPA Classification"
#
# $V12
# [1] "Base Curb Weight (lbs)"
#
# $V13
# [1] "Front Hip Room (in)"
#
# $V14
# [1] "Front Leg Room (in)"
#
# $V15
# [1] "Second Shoulder Room (in)"
#
# $V16
# [1] "Passenger Volume (ft³)"
#
# $V17
# [1] "Second Head Room (in)"
#
# $V18
# [1] "Front Shoulder Room (in)"
#
# $V19
# [1] "Second Hip Room (in)"
#
# $V20
# [1] "Front Head Room (in)"
#
# $V21
# [1] "Second Leg Room (in)"
#
# $V22
# [1] "Wheelbase (in)"
#
# $V23
# [1] "Min Ground Clearance (in)"
#
# $V24
# [1] "Track Width, Front (in)"
#
# $V25
# [1] "Width, Max w/o mirrors (in)"
#
# $V26
# [1] "Track Width, Rear (in)"
#
# $V27
# [1] "Height, Overall (in)"
#
# $V28
# ...

# %%
colnames(dataset) = c(dataset[(1),])

# %%
head(dataset,2)
# Out:
#   X                                           MSRP    Gas Mileage
# 1 X                                           MSRP    Gas Mileage
# 2 X2019.Acura.RDX.Specs..FWD.w.Technology.Pkg $40,600 22 mpg City/28 mpg Hwy
#   Engine                            EPA Class
# 1 Engine                            EPA Class
# 2 Turbo Premium Unleaded I-4, 2.0 L Small Sport Utility Vehicles 2WD
#   Style Name           Drivetrain        Passenger Capacity Passenger Doors
# 1 Style Name           Drivetrain        Passenger Capacity Passenger Doors
# 2 FWD w/Technology Pkg Front Wheel Drive 5                  4
#   Body Style    ⋯ Fourth Hip Room (in) Fourth Leg Room (in)
# 1 Body Style    ⋯ Fourth Hip Room (in) Fourth Leg Room (in)
# 2 Sport Utility ⋯ NA                   NA
#   Fourth Shoulder Room (in) Fourth Head Room (in) Fifth Shoulder Room (in)
# 1 Fourth Shoulder Room (in) Fourth Head Room (in) Fifth Shoulder Room (in)
# 2 NA                        NA                    NA
# ...

# %%
colnames(dataset)
# Out:
#   [1] "X"
#   [2] "MSRP"
#   [3] "Gas Mileage"
#   [4] "Engine"
#   [5] "EPA Class"
#   [6] "Style Name"
#   [7] "Drivetrain"
#   [8] "Passenger Capacity"
#   [9] "Passenger Doors"
#  [10] "Body Style"
#  [11] "Transmission"
#  [12] "EPA Classification"
#  [13] "Base Curb Weight (lbs)"
#  [14] "Front Hip Room (in)"
#  [15] "Front Leg Room (in)"
#  [16] "Second Shoulder Room (in)"
#  [17] "Passenger Volume (ft³)"
#  [18] "Second Head Room (in)"
#  [19] "Front Shoulder Room (in)"
#  [20] "Second Hip Room (in)"
#  [21] "Front Head Room (in)"
#  [22] "Second Leg Room (in)"
#  [23] "Wheelbase (in)"
#  [24] "Min Ground Clearance (in)"
#  [25] "Track Width, Front (in)"
#  [26] "Width, Max w/o mirrors (in)"
#  [27] "Track Width, Rear (in)"
#  [28] "Height, Overall (in)"
#  [29] "Cargo Volume to Seat 1 (ft³)"
#  [30] "Cargo Volume to Seat 2 (ft³)"
#  [31] "Cargo Volume to Seat 3 (ft³)"
#  [32] "Fuel Tank Capacity, Approx (gal)"
#  [33] "Fuel Economy Est-Combined (MPG)"
# ...

# %%
lapply(dataset, function(x) { length(which(is.na(x)))})
# Out:
# $X
# [1] 0
#
# $MSRP
# [1] 4
#
# $`Gas Mileage`
# [1] 6024
#
# $Engine
# [1] 1975
#
# $`EPA Class`
# [1] 1976
#
# $`Style Name`
# [1] 0
#
# $Drivetrain
# [1] 1716
#
# $`Passenger Capacity`
# [1] 0
#
# $`Passenger Doors`
# [1] 0
#
# $`Body Style`
# [1] 1716
#
# $Transmission
# [1] 2714
#
# $`EPA Classification`
# [1] 12391
#
# $`Base Curb Weight (lbs)`
# [1] 12597
#
# $`Front Hip Room (in)`
# [1] 4726
#
# $`Front Leg Room (in)`
# [1] 2493
#
# $`Second Shoulder Room (in)`
# [1] 5599
#
# $`Passenger Volume (ft³)`
# [1] 14101
#
# $`Second Head Room (in)`
# [1] 5561
#
# $`Front Shoulder Room (in)`
# [1] 2536
#
# $`Second Hip Room (in)`
# [1] 7608
#
# $`Front Head Room (in)`
# [1] 2543
#
# $`Second Leg Room (in)`
# [1] 5544
#
# $`Wheelbase (in)`
# [1] 1971
#
# $`Min Ground Clearance (in)`
# [1] 14434
#
# $`Track Width, Front (in)`
# [1] 11857
#
# $`Width, Max w/o mirrors (in)`
# [1] 2050
#
# $`Track Width, Rear (in)`
# [1] 11858
#
# $`Height, Overall (in)`
# [1] 2018
#
# ...

# %%
lapply(dataset, function(x) { length(which(is.na(x)))})<32000
# Out:
#                                             X
#                                          TRUE
#                                          MSRP
#                                          TRUE
#                                   Gas Mileage
#                                          TRUE
#                                        Engine
#                                          TRUE
#                                     EPA Class
#                                          TRUE
#                                    Style Name
#                                          TRUE
#                                    Drivetrain
#                                          TRUE
#                            Passenger Capacity
#                                          TRUE
#                               Passenger Doors
#                                          TRUE
#                                    Body Style
#                                          TRUE
# ...
